# %%
#Making the imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(12,9)

# %%
#Preprocessing input data
data=pd.read_csv('bike_sharing_data.txt')
x=data.iloc[:,0]
y=data.iloc[:,1]
plt.scatter(x,y)

# %%
#Building the model
m=0
c=0
l=0.0001
epochs=1000

n=float(len(x))
for i in range(len(x)):
    y_pred=m*x+c
    D_m=(-2/n)*sum(x*(y-y_pred))
    D_c=(-2/n)*sum(y-y_pred)
    m=m-l*D_m
    c=c-l*D_c
    
print(m,c)
# Out:
# 0.6361498482434664 0.049889609317632165

# %%
#Making predictions
y_pred=m*x+c

plt.scatter(x,y)
plt.plot([min(x),max(x)],[min(y_pred),max(y_pred)],color='red')
